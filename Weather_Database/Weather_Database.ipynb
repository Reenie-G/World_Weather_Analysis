# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import time
from datetime import datetime
from citipy import citipy

# %%
# Create a new set of 2000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# Create a list for holding the cities

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data

city_data =[]

# Print the beginning of the logging

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create the counters

record_count = 1
set_count = 1



# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kargasok
# Processing Record 2 of Set 1 | taoudenni
# Processing Record 3 of Set 1 | wazzan
# City not found. Skipping...
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | taywarah
# Processing Record 6 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 1 | yakeshi
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | kazuno
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | ritchie
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | tazovskiy
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | tomatlan
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | antas
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | ulladulla
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | hualmay
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | middle island
# Processing Record 31 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 1 | pecos
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | mitu
# Processing Record 42 of Set 1 | innisfail
# Processing Record 43 of Set 1 | vestmannaeyjar
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | itarema
# Processing Record 46 of Set 1 | eldorado
# Processing Record 47 of Set 1 | kawambwa
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | elbasan
# Processing Record 1 of Set 2 | patiya
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | oiso
# Processing Record 5 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | bourail
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | bilma
# Processing Record 12 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 2 | bad krozingen
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | yeppoon
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | izvoarele
# Processing Record 21 of Set 2 | mtsensk
# Processing Record 22 of Set 2 | rancho palos verdes
# Processing Record 23 of Set 2 | sorland
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | bathsheba
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | dudinka
# Processing Record 33 of Set 2 | muriwai beach
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | mabini
# Processing Record 36 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 2 | grindavik
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | puerto baquerizo moreno
# Processing Record 40 of Set 2 | orocue
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | mpika
# Processing Record 44 of Set 2 | tocopilla
# Processing Record 45 of Set 2 | severo-yeniseyskiy
# Processing Record 46 of Set 2 | sechura
# Processing Record 47 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 2 | west memphis
# Processing Record 49 of Set 2 | lensk
# Processing Record 50 of Set 2 | arrecife
# Processing Record 1 of Set 3 | sinnamary
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | tubarao
# Processing Record 4 of Set 3 | riyadh
# Processing Record 5 of Set 3 | bilibino
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | anloga
# Processing Record 8 of Set 3 | mackenzie
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | constitucion
# Processing Record 11 of Set 3 | linxia
# Processing Record 12 of Set 3 | paita
# Processing Record 13 of Set 3 | barranca
# Processing Record 14 of Set 3 | shingu
# Processing Record 15 of Set 3 | seoul
# Processing Record 16 of Set 3 | korla
# Processing Record 17 of Set 3 | lebyazhye
# Processing Record 18 of Set 3 | caborca
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | buraydah
# Processing Record 22 of Set 3 | burnie
# Processing Record 23 of Set 3 | tautira
# Processing Record 24 of Set 3 | potgietersrus
# City not found. Skipping...
# Processing Record 25 of Set 3 | namibe
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | moose factory
# Processing Record 28 of Set 3 | tianpeng
# Processing Record 29 of Set 3 | nacala
# Processing Record 30 of Set 3 | alta floresta
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | itaituba
# Processing Record 34 of Set 3 | guspini
# Processing Record 35 of Set 3 | college
# Processing Record 36 of Set 3 | hargeysa
# Processing Record 37 of Set 3 | ushuaia
# Processing Record 38 of Set 3 | muzhi
# Processing Record 39 of Set 3 | auki
# Processing Record 40 of Set 3 | caravelas
# Processing Record 41 of Set 3 | te anau
# Processing Record 42 of Set 3 | huarmey
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | zhangye
# Processing Record 45 of Set 3 | kyzyl-suu
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | muros
# Processing Record 49 of Set 3 | mitsamiouli
# Processing Record 50 of Set 3 | tome-acu
# City not found. Skipping...
# Processing Record 1 of Set 4 | merritt island
# Processing Record 2 of Set 4 | rincon
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 5 of Set 4 | saint-francois
# Processing Record 6 of Set 4 | richards bay
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | ternate
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | prainha
# Processing Record 12 of Set 4 | katobu
# Processing Record 13 of Set 4 | oum hadjer
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | we
# City not found. Skipping...
# Processing Record 16 of Set 4 | ulaangom
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | utete
# Processing Record 20 of Set 4 | flin flon
# Processing Record 21 of Set 4 | fethiye
# Processing Record 22 of Set 4 | ostuacan
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | port hedland
# Processing Record 26 of Set 4 | baruun-urt
# Processing Record 27 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 4 | keighley
# Processing Record 29 of Set 4 | lorengau
# Processing Record 30 of Set 4 | zaida
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | mayna
# Processing Record 33 of Set 4 | leh
# Processing Record 34 of Set 4 | dongli
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | south venice
# Processing Record 37 of Set 4 | price
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | petauke
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | khomutovo
# Processing Record 43 of Set 4 | aginskoye
# Processing Record 44 of Set 4 | placido de castro
# Processing Record 45 of Set 4 | fortuna
# Processing Record 46 of Set 4 | merauke
# Processing Record 47 of Set 4 | deputatskiy
# Processing Record 48 of Set 4 | gushikawa
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | champerico
# Processing Record 1 of Set 5 | nazret
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | sovetskiy
# Processing Record 4 of Set 5 | saldanha
# Processing Record 5 of Set 5 | talara
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | san policarpo
# Processing Record 8 of Set 5 | boa vista
# Processing Record 9 of Set 5 | nikolskoye
# Processing Record 10 of Set 5 | galle
# Processing Record 11 of Set 5 | tiksi
# Processing Record 12 of Set 5 | biak
# Processing Record 13 of Set 5 | tuktoyaktuk
# Processing Record 14 of Set 5 | norsup
# Processing Record 15 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 5 | ajdabiya
# Processing Record 17 of Set 5 | khandyga
# Processing Record 18 of Set 5 | ahipara
# Processing Record 19 of Set 5 | waingapu
# Processing Record 20 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 5 | saint-augustin
# Processing Record 22 of Set 5 | jardim
# Processing Record 23 of Set 5 | khani
# Processing Record 24 of Set 5 | san cristobal
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | kikwit
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | poum
# Processing Record 29 of Set 5 | dunedin
# Processing Record 30 of Set 5 | honiara
# Processing Record 31 of Set 5 | tatawin
# Processing Record 32 of Set 5 | maceio
# Processing Record 33 of Set 5 | palmer
# Processing Record 34 of Set 5 | husavik
# Processing Record 35 of Set 5 | taltal
# Processing Record 36 of Set 5 | kismayo
# Processing Record 37 of Set 5 | orodara
# Processing Record 38 of Set 5 | saint-michel-des-saints
# Processing Record 39 of Set 5 | itirucu
# Processing Record 40 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 5 | ponta delgada
# Processing Record 42 of Set 5 | tokonou
# Processing Record 43 of Set 5 | berlevag
# Processing Record 44 of Set 5 | limon
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | nara
# Processing Record 47 of Set 5 | hamilton
# Processing Record 48 of Set 5 | tigil
# Processing Record 49 of Set 5 | rab
# City not found. Skipping...
# Processing Record 50 of Set 5 | graham
# Processing Record 1 of Set 6 | pochutla
# Processing Record 2 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 6 | shirokaya rechka
# Processing Record 4 of Set 6 | anzio
# Processing Record 5 of Set 6 | kirakira
# Processing Record 6 of Set 6 | qibili
# City not found. Skipping...
# Processing Record 7 of Set 6 | tasiilaq
# Processing Record 8 of Set 6 | meulaboh
# Processing Record 9 of Set 6 | sur
# Processing Record 10 of Set 6 | avera
# Processing Record 11 of Set 6 | cavalcante
# Processing Record 12 of Set 6 | vynohradove
# Processing Record 13 of Set 6 | aiquile
# Processing Record 14 of Set 6 | bushehr
# Processing Record 15 of Set 6 | batemans bay
# Processing Record 16 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 6 | esperance
# Processing Record 18 of Set 6 | isla vista
# Processing Record 19 of Set 6 | miraflores
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | samarai
# Processing Record 22 of Set 6 | saint george
# Processing Record 23 of Set 6 | the pas
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | christchurch
# Processing Record 27 of Set 6 | kijang
# Processing Record 28 of Set 6 | vuktyl
# Processing Record 29 of Set 6 | basco
# Processing Record 30 of Set 6 | sladkovo
# Processing Record 31 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 32 of Set 6 | takoradi
# Processing Record 33 of Set 6 | trincomalee
# Processing Record 34 of Set 6 | geraldton
# Processing Record 35 of Set 6 | katangli
# Processing Record 36 of Set 6 | lubango
# Processing Record 37 of Set 6 | bara
# Processing Record 38 of Set 6 | shizukuishi
# Processing Record 39 of Set 6 | ola
# Processing Record 40 of Set 6 | yerbogachen
# Processing Record 41 of Set 6 | padre bernardo
# Processing Record 42 of Set 6 | veisiejai
# Processing Record 43 of Set 6 | fort nelson
# Processing Record 44 of Set 6 | pishin
# Processing Record 45 of Set 6 | ugoofaaru
# Processing Record 46 of Set 6 | emerald
# Processing Record 47 of Set 6 | faya
# Processing Record 48 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | zemio
# Processing Record 1 of Set 7 | lompoc
# Processing Record 2 of Set 7 | port shepstone
# Processing Record 3 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 7 | sao filipe
# Processing Record 5 of Set 7 | warrnambool
# Processing Record 6 of Set 7 | asau
# Processing Record 7 of Set 7 | maniitsoq
# Processing Record 8 of Set 7 | san quintin
# Processing Record 9 of Set 7 | ranong
# Processing Record 10 of Set 7 | omsukchan
# Processing Record 11 of Set 7 | akdagmadeni
# Processing Record 12 of Set 7 | vostok
# Processing Record 13 of Set 7 | roald
# Processing Record 14 of Set 7 | peachland
# Processing Record 15 of Set 7 | kilakarai
# Processing Record 16 of Set 7 | lata
# Processing Record 17 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 7 | kelapa sawit
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | luxor
# Processing Record 21 of Set 7 | norman wells
# Processing Record 22 of Set 7 | cabedelo
# Processing Record 23 of Set 7 | arlit
# Processing Record 24 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 7 | jizan
# Processing Record 26 of Set 7 | ferme-neuve
# Processing Record 27 of Set 7 | kudahuvadhoo
# Processing Record 28 of Set 7 | brattleboro
# Processing Record 29 of Set 7 | shenkursk
# Processing Record 30 of Set 7 | moissala
# Processing Record 31 of Set 7 | banda aceh
# Processing Record 32 of Set 7 | lubao
# Processing Record 33 of Set 7 | henties bay
# Processing Record 34 of Set 7 | ramona
# Processing Record 35 of Set 7 | sao miguel dos campos
# Processing Record 36 of Set 7 | mgandu
# Processing Record 37 of Set 7 | ahuimanu
# Processing Record 38 of Set 7 | zhigansk
# Processing Record 39 of Set 7 | nelson bay
# Processing Record 40 of Set 7 | diego de almagro
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | wau
# Processing Record 44 of Set 7 | torbay
# Processing Record 45 of Set 7 | yumen
# Processing Record 46 of Set 7 | harrisonburg
# Processing Record 47 of Set 7 | vila franca do campo
# Processing Record 48 of Set 7 | kununurra
# Processing Record 49 of Set 7 | khatanga
# Processing Record 50 of Set 7 | valparaiso
# Processing Record 1 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 8 | nishihara
# Processing Record 3 of Set 8 | carnarvon
# Processing Record 4 of Set 8 | taupo
# Processing Record 5 of Set 8 | kyabe
# Processing Record 6 of Set 8 | itoman
# Processing Record 7 of Set 8 | stromness
# Processing Record 8 of Set 8 | springbok
# Processing Record 9 of Set 8 | noyabrsk
# Processing Record 10 of Set 8 | bandarbeyla
# Processing Record 11 of Set 8 | wainwright
# Processing Record 12 of Set 8 | zyryanka
# Processing Record 13 of Set 8 | seymchan
# Processing Record 14 of Set 8 | port keats
# Processing Record 15 of Set 8 | belaya gora
# Processing Record 16 of Set 8 | oranjemund
# Processing Record 17 of Set 8 | saint anthony
# Processing Record 18 of Set 8 | kandrian
# Processing Record 19 of Set 8 | flinders
# Processing Record 20 of Set 8 | shimanovsk
# Processing Record 21 of Set 8 | quelimane
# Processing Record 22 of Set 8 | ramhormoz
# Processing Record 23 of Set 8 | wilmington
# Processing Record 24 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 8 | pakwach
# City not found. Skipping...
# Processing Record 26 of Set 8 | chany
# Processing Record 27 of Set 8 | paola
# Processing Record 28 of Set 8 | martil
# Processing Record 29 of Set 8 | luderitz
# Processing Record 30 of Set 8 | maumere
# Processing Record 31 of Set 8 | cap malheureux
# Processing Record 32 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 33 of Set 8 | kendari
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | puerto madryn
# Processing Record 36 of Set 8 | fairbanks
# Processing Record 37 of Set 8 | biltine
# Processing Record 38 of Set 8 | oro valley
# Processing Record 39 of Set 8 | kabwe
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 42 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 8 | adrar
# Processing Record 44 of Set 8 | ponta do sol
# Processing Record 45 of Set 8 | mayo
# Processing Record 46 of Set 8 | ust-nera
# Processing Record 47 of Set 8 | dungarvan
# Processing Record 48 of Set 8 | hofn
# Processing Record 49 of Set 8 | udachnyy
# Processing Record 50 of Set 8 | cayenne
# Processing Record 1 of Set 9 | tilichiki
# Processing Record 2 of Set 9 | amapa
# Processing Record 3 of Set 9 | ayorou
# Processing Record 4 of Set 9 | victoria
# Processing Record 5 of Set 9 | ust-kuyga
# Processing Record 6 of Set 9 | svetlogorsk
# Processing Record 7 of Set 9 | tirumullaivasal
# Processing Record 8 of Set 9 | waitakere
# Processing Record 9 of Set 9 | mountain home
# Processing Record 10 of Set 9 | mangai
# Processing Record 11 of Set 9 | rio branco
# Processing Record 12 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 9 | okhotsk
# Processing Record 14 of Set 9 | hami
# Processing Record 15 of Set 9 | acarau
# Processing Record 16 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 9 | nemuro
# Processing Record 18 of Set 9 | myslenice
# Processing Record 19 of Set 9 | puerto del rosario
# Processing Record 20 of Set 9 | garden city
# Processing Record 21 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | talcahuano
# Processing Record 23 of Set 9 | praia
# Processing Record 24 of Set 9 | vao
# Processing Record 25 of Set 9 | morondava
# Processing Record 26 of Set 9 | krasnoarmeyskiy
# Processing Record 27 of Set 9 | kamakwie
# Processing Record 28 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 9 | marsh harbour
# Processing Record 30 of Set 9 | klyuchi
# Processing Record 31 of Set 9 | burgeo
# Processing Record 32 of Set 9 | chok chai
# Processing Record 33 of Set 9 | kavaratti
# Processing Record 34 of Set 9 | sao joao da barra
# Processing Record 35 of Set 9 | ntchisi
# Processing Record 36 of Set 9 | ostrovnoy
# Processing Record 37 of Set 9 | zamora
# Processing Record 38 of Set 9 | youghal
# Processing Record 39 of Set 9 | makakilo city
# Processing Record 40 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 9 | santa maria da boa vista
# Processing Record 42 of Set 9 | edd
# Processing Record 43 of Set 9 | chum phae
# Processing Record 44 of Set 9 | darovskoy
# Processing Record 45 of Set 9 | karratha
# Processing Record 46 of Set 9 | grand gaube
# Processing Record 47 of Set 9 | pascagoula
# Processing Record 48 of Set 9 | cidreira
# Processing Record 49 of Set 9 | labuhan
# Processing Record 50 of Set 9 | malaia
# Processing Record 1 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 10 | dadu
# Processing Record 3 of Set 10 | whitehorse
# Processing Record 4 of Set 10 | soufriere
# Processing Record 5 of Set 10 | la ronge
# Processing Record 6 of Set 10 | phan thiet
# Processing Record 7 of Set 10 | genhe
# Processing Record 8 of Set 10 | abyek
# Processing Record 9 of Set 10 | qaqortoq
# Processing Record 10 of Set 10 | kruisfontein
# Processing Record 11 of Set 10 | tondano
# Processing Record 12 of Set 10 | andenes
# Processing Record 13 of Set 10 | bagdarin
# Processing Record 14 of Set 10 | mackay
# Processing Record 15 of Set 10 | ambulu
# Processing Record 16 of Set 10 | adana
# Processing Record 17 of Set 10 | jedrzejow
# Processing Record 18 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 19 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 10 | vavuniya
# Processing Record 21 of Set 10 | san patricio
# Processing Record 22 of Set 10 | kyaka
# Processing Record 23 of Set 10 | muli
# Processing Record 24 of Set 10 | ossora
# Processing Record 25 of Set 10 | aswan
# Processing Record 26 of Set 10 | springfield
# Processing Record 27 of Set 10 | jalu
# Processing Record 28 of Set 10 | manokwari
# Processing Record 29 of Set 10 | mao
# Processing Record 30 of Set 10 | nome
# Processing Record 31 of Set 10 | itaqui
# Processing Record 32 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 10 | kenai
# Processing Record 34 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 10 | tevaitoa
# Processing Record 36 of Set 10 | alofi
# Processing Record 37 of Set 10 | sal rei
# Processing Record 38 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 39 of Set 10 | moerai
# Processing Record 40 of Set 10 | xining
# Processing Record 41 of Set 10 | aviles
# Processing Record 42 of Set 10 | keta
# Processing Record 43 of Set 10 | lockhart
# Processing Record 44 of Set 10 | ambilobe
# Processing Record 45 of Set 10 | adre
# Processing Record 46 of Set 10 | anajatuba
# Processing Record 47 of Set 10 | rogongon
# Processing Record 48 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 10 | iqaluit
# Processing Record 50 of Set 10 | makung
# City not found. Skipping...
# Processing Record 1 of Set 11 | khudumelapye
# Processing Record 2 of Set 11 | port hardy
# Processing Record 3 of Set 11 | santa comba
# Processing Record 4 of Set 11 | rockingham
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | bull savanna
# Processing Record 7 of Set 11 | homer
# Processing Record 8 of Set 11 | liminangcong
# City not found. Skipping...
# Processing Record 9 of Set 11 | guerrero negro
# Processing Record 10 of Set 11 | lasa
# Processing Record 11 of Set 11 | kachiry
# Processing Record 12 of Set 11 | touros
# Processing Record 13 of Set 11 | hangu
# Processing Record 14 of Set 11 | luanda
# Processing Record 15 of Set 11 | provideniya
# Processing Record 16 of Set 11 | pangody
# Processing Record 17 of Set 11 | tavda
# Processing Record 18 of Set 11 | lagoa
# Processing Record 19 of Set 11 | sembe
# Processing Record 20 of Set 11 | peniche
# Processing Record 21 of Set 11 | besikduzu
# Processing Record 22 of Set 11 | mahajanga
# Processing Record 23 of Set 11 | augustow
# Processing Record 24 of Set 11 | nyimba
# Processing Record 25 of Set 11 | chynov
# Processing Record 26 of Set 11 | calmar
# Processing Record 27 of Set 11 | nanortalik
# Processing Record 28 of Set 11 | zhezkazgan
# Processing Record 29 of Set 11 | smirnykh
# Processing Record 30 of Set 11 | tahta
# Processing Record 31 of Set 11 | lima
# Processing Record 32 of Set 11 | lekoni
# Processing Record 33 of Set 11 | laguna
# Processing Record 34 of Set 11 | wodonga
# Processing Record 35 of Set 11 | quzhou
# Processing Record 36 of Set 11 | lansing
# Processing Record 37 of Set 11 | chicama
# Processing Record 38 of Set 11 | teya
# Processing Record 39 of Set 11 | rabaul
# Processing Record 40 of Set 11 | lucapa
# Processing Record 41 of Set 11 | felipe carrillo puerto
# Processing Record 42 of Set 11 | youhao
# Processing Record 43 of Set 11 | bonavista
# Processing Record 44 of Set 11 | gizo
# Processing Record 45 of Set 11 | iskateley
# Processing Record 46 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 11 | mount isa
# Processing Record 48 of Set 11 | ucluelet
# Processing Record 49 of Set 11 | tual
# Processing Record 50 of Set 11 | hays
# Processing Record 1 of Set 12 | tomaszow lubelski
# Processing Record 2 of Set 12 | malakisi
# City not found. Skipping...
# Processing Record 3 of Set 12 | monte alegre
# Processing Record 4 of Set 12 | kichera
# Processing Record 5 of Set 12 | denpasar
# Processing Record 6 of Set 12 | kuva
# City not found. Skipping...
# Processing Record 7 of Set 12 | vestmanna
# Processing Record 8 of Set 12 | sao jose da coroa grande
# Processing Record 9 of Set 12 | jiexiu
# Processing Record 10 of Set 12 | port augusta
# Processing Record 11 of Set 12 | krasnoselkup
# Processing Record 12 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 12 | romanshorn
# Processing Record 14 of Set 12 | coihaique
# Processing Record 15 of Set 12 | nizhniy kuranakh
# Processing Record 16 of Set 12 | nouadhibou
# Processing Record 17 of Set 12 | sawtell
# Processing Record 18 of Set 12 | kapoeta
# Processing Record 19 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 12 | coquimbo
# Processing Record 21 of Set 12 | kieta
# Processing Record 22 of Set 12 | isla del bosque
# Processing Record 23 of Set 12 | beloha
# Processing Record 24 of Set 12 | terme
# Processing Record 25 of Set 12 | umarga
# Processing Record 26 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 27 of Set 12 | rapid valley
# Processing Record 28 of Set 12 | sterlibashevo
# Processing Record 29 of Set 12 | omboue
# Processing Record 30 of Set 12 | verkhoyansk
# Processing Record 31 of Set 12 | north bend
# Processing Record 32 of Set 12 | haines junction
# Processing Record 33 of Set 12 | rocha
# Processing Record 34 of Set 12 | hay river
# Processing Record 35 of Set 12 | yarim
# Processing Record 36 of Set 12 | wajir
# Processing Record 37 of Set 12 | makokou
# Processing Record 38 of Set 12 | palana
# Processing Record 39 of Set 12 | inta
# Processing Record 40 of Set 12 | bodden town
# Processing Record 41 of Set 12 | russell
# Processing Record 42 of Set 12 | umm lajj
# Processing Record 43 of Set 12 | antofagasta
# Processing Record 44 of Set 12 | sobolevo
# Processing Record 45 of Set 12 | najran
# Processing Record 46 of Set 12 | anadyr
# Processing Record 47 of Set 12 | sydney
# Processing Record 48 of Set 12 | ayotzintepec
# Processing Record 49 of Set 12 | mkushi
# Processing Record 50 of Set 12 | novyy urengoy
# Processing Record 1 of Set 13 | kodala
# Processing Record 2 of Set 13 | pacific grove
# Processing Record 3 of Set 13 | hobyo
# Processing Record 4 of Set 13 | harbin
# Processing Record 5 of Set 13 | groningen
# Processing Record 6 of Set 13 | toora-khem
# Processing Record 7 of Set 13 | naryan-mar
# Processing Record 8 of Set 13 | ivdel
# Processing Record 9 of Set 13 | mechetinskaya
# Processing Record 10 of Set 13 | narsaq
# Processing Record 11 of Set 13 | northam
# Processing Record 12 of Set 13 | pevek
# Processing Record 13 of Set 13 | malakal
# Processing Record 14 of Set 13 | betioky
# Processing Record 15 of Set 13 | rawson
# Processing Record 16 of Set 13 | rabo de peixe
# Processing Record 17 of Set 13 | vrangel
# Processing Record 18 of Set 13 | southbridge
# Processing Record 19 of Set 13 | abhar
# Processing Record 20 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 13 | port blair
# Processing Record 22 of Set 13 | caucaia
# Processing Record 23 of Set 13 | saint-joseph
# Processing Record 24 of Set 13 | bo rai
# Processing Record 25 of Set 13 | yar-sale
# Processing Record 26 of Set 13 | kalaleh
# Processing Record 27 of Set 13 | araouane
# Processing Record 28 of Set 13 | marsa matruh
# Processing Record 29 of Set 13 | imbituba
# Processing Record 30 of Set 13 | antsirabe
# Processing Record 31 of Set 13 | murakami
# Processing Record 32 of Set 13 | aspindza
# Processing Record 33 of Set 13 | koboldo
# City not found. Skipping...
# Processing Record 34 of Set 13 | port-gentil
# Processing Record 35 of Set 13 | aguimes
# Processing Record 36 of Set 13 | tamale
# Processing Record 37 of Set 13 | belyy yar
# Processing Record 38 of Set 13 | kang
# Processing Record 39 of Set 13 | eschwege
# Processing Record 40 of Set 13 | barcelona
# Processing Record 41 of Set 13 | tuskegee
# Processing Record 42 of Set 13 | watsa
# Processing Record 43 of Set 13 | nyurba
# Processing Record 44 of Set 13 | los llanos de aridane
# Processing Record 45 of Set 13 | kawalu
# Processing Record 46 of Set 13 | broome
# Processing Record 47 of Set 13 | ambon
# Processing Record 48 of Set 13 | san jose
# Processing Record 49 of Set 13 | birao
# Processing Record 50 of Set 13 | kamarion
# Processing Record 1 of Set 14 | rotterdam
# Processing Record 2 of Set 14 | senneterre
# Processing Record 3 of Set 14 | viamao
# Processing Record 4 of Set 14 | dovers
# Processing Record 5 of Set 14 | ixtapa
# Processing Record 6 of Set 14 | nagapattinam
# Processing Record 7 of Set 14 | spitak
# Processing Record 8 of Set 14 | shafranovo
# Processing Record 9 of Set 14 | banyo
# Processing Record 10 of Set 14 | balaipungut
# Processing Record 11 of Set 14 | tabou
# Processing Record 12 of Set 14 | monforte de lemos
# Processing Record 13 of Set 14 | varhaug
# Processing Record 14 of Set 14 | olinda
# Processing Record 15 of Set 14 | santa maria
# Processing Record 16 of Set 14 | yeniseysk
# Processing Record 17 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 14 | dali
# Processing Record 19 of Set 14 | aksarka
# Processing Record 20 of Set 14 | porbandar
# Processing Record 21 of Set 14 | komsomolskiy
# Processing Record 22 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 14 | tuy hoa
# Processing Record 24 of Set 14 | camopi
# Processing Record 25 of Set 14 | barkly west
# Processing Record 26 of Set 14 | buala
# Processing Record 27 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 14 | beyneu
# Processing Record 29 of Set 14 | jodiya
# Processing Record 30 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 14 | ambo
# Processing Record 32 of Set 14 | marystown
# Processing Record 33 of Set 14 | shadrinsk
# Processing Record 34 of Set 14 | mecca
# Processing Record 35 of Set 14 | japura
# Processing Record 36 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 37 of Set 14 | bumba
# Processing Record 38 of Set 14 | nizwa
# Processing Record 39 of Set 14 | rio gallegos
# Processing Record 40 of Set 14 | berezovka
# Processing Record 41 of Set 14 | houlton
# Processing Record 42 of Set 14 | caramay
# Processing Record 43 of Set 14 | sangin
# Processing Record 44 of Set 14 | nantucket
# Processing Record 45 of Set 14 | viljoenskroon
# Processing Record 46 of Set 14 | havre-saint-pierre
# Processing Record 47 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 14 | kidal
# Processing Record 49 of Set 14 | katsuura
# Processing Record 50 of Set 14 | belmonte
# Processing Record 1 of Set 15 | iquique
# Processing Record 2 of Set 15 | pokhara
# Processing Record 3 of Set 15 | puri
# Processing Record 4 of Set 15 | deniliquin
# Processing Record 5 of Set 15 | morant bay
# Processing Record 6 of Set 15 | tongren
# Processing Record 7 of Set 15 | port hawkesbury
# Processing Record 8 of Set 15 | lavrentiya
# Processing Record 9 of Set 15 | kampong cham
# Processing Record 10 of Set 15 | mikuni
# Processing Record 11 of Set 15 | hambantota
# Processing Record 12 of Set 15 | paamiut
# Processing Record 13 of Set 15 | lumphat
# Processing Record 14 of Set 15 | barauna
# Processing Record 15 of Set 15 | yulara
# Processing Record 16 of Set 15 | jiaojiang
# Processing Record 17 of Set 15 | nana
# Processing Record 18 of Set 15 | dickinson
# Processing Record 19 of Set 15 | puerto madero
# Processing Record 20 of Set 15 | dagua
# Processing Record 21 of Set 15 | posse
# Processing Record 22 of Set 15 | inhambane
# Processing Record 23 of Set 15 | olafsvik
# Processing Record 24 of Set 15 | sarankhola
# Processing Record 25 of Set 15 | wiarton
# Processing Record 26 of Set 15 | poco branco
# Processing Record 27 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 28 of Set 15 | kapuskasing
# Processing Record 29 of Set 15 | den helder
# Processing Record 30 of Set 15 | praya
# -----------------------------
# Data Retrieval Complete

# %%
len(cities)
# Out:
# 730

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Kargasok      RU  59.0556   80.8572     66.09        80          78
# 1  Taoudenni      ML  22.6783   -3.9836    111.97         5           0
# 2    Mataura      NZ -46.1927  168.8643     35.47        93          29
# 3   Taywarah      AF  33.3500   64.4167     64.87        18           1
# 4    Yakeshi      CN  49.2833  120.7333     53.82        90         100
# 5     Castro      BR -24.7911  -50.0119     71.65        45          55
# 6     Kazuno      JP  40.1836  140.7872     66.56        98          95
# 7  Hithadhoo      MV  -0.6000   73.0833     82.45        76          13
# 8   Souillac      MU -20.5167   57.5167     68.38        68          40
# 9    Ritchie      ZA -29.0380   24.6028     54.61        42           0
#
#    Wind Speed Current Description
# 0        7.05       broken clouds
# 1       12.95           clear sky
# 2        2.01    scattered clouds
# 3        7.02           clear sky
# 4        4.83     overcast clouds
# 5        6.17       broken clouds
# 6        2.24          light rain
# 7        5.59          few clouds
# 8       14.97    scattered clouds
# 9       10.54           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
